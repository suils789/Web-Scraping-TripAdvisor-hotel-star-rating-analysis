# %% [markdown]
# # Analyzing Hotel Ratings on Tripadvisor

# %% [markdown]
# In this homework, we will analyze the data we scraped in Part 1 by fitting a regression model on the data.

# %% [markdown]
# ** Task 1 (20 pts) **
#
# Now, we will use regression to analyze this information. First, we will fit a linear regression model that predicts the average rating.
#
# For example, the average rating of a hotel is calculated as follows:
#
# ![Information to be scraped](traveler_ratings.png)
#
# $$ \text{AVG_SCORE} = \frac{1*15 + 2*21 + 3*55 + 4*228 + 5*1271}{1590}$$
#
# Use the model to analyze the important factors that decide the $\text{AVG_SCORE}$.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('part1.csv')

# %%
data
# Out:
#      Unnamed: 0                                         hotel_name     rating  \
# 0             0  Marriott Vacation Club Pulse at Custom House, ...  Excellent
# 1             1  Marriott Vacation Club Pulse at Custom House, ...  Very good
# 2             2  Marriott Vacation Club Pulse at Custom House, ...    Average
# 3             3  Marriott Vacation Club Pulse at Custom House, ...       Poor
# 4             4  Marriott Vacation Club Pulse at Custom House, ...   Terrible
# 5             5                                Boston Harbor Hotel  Excellent
# 6             6                                Boston Harbor Hotel  Very good
# 7             7                                Boston Harbor Hotel    Average
# 8             8                                Boston Harbor Hotel       Poor
# 9             9                                Boston Harbor Hotel   Terrible
# 10           10                               Seaport Boston Hotel  Excellent
# 11           11                               Seaport Boston Hotel  Very good
# 12           12                               Seaport Boston Hotel    Average
# 13           13                               Seaport Boston Hotel       Poor
# 14           14                               Seaport Boston Hotel   Terrible
# 15           15                          Four Seasons Hotel Boston  Excellent
# 16           16                          Four Seasons Hotel Boston  Very good
# 17           17                          Four Seasons Hotel Boston    Average
# 18           18                          Four Seasons Hotel Boston       Poor
# 19           19                          Four Seasons Hotel Boston   Terrible
# 20           20                                        Lenox Hotel  Excellent
# 21           21                                        Lenox Hotel  Very good
# 22           22                                        Lenox Hotel    Average
# 23           23                                        Lenox Hotel       Poor
# 24           24                                        Lenox Hotel   Terrible
# 25           25                     Courtyard Boston Copley Square  Excellent
# 26           26                     Courtyard Boston Copley Square  Very good
# 27           27                     Courtyard Boston Copley Square    Average
# 28           28                     Courtyard Boston Copley Square       Poor
# 29           29                     Courtyard Boston Copley Square   Terrible
# ..          ...                                                ...        ...
# 380         380                                      Ramada Boston  Excellent
# 381         381                                      Ramada Boston  Very good
# 382         382                                      Ramada Boston    Average
# 383         383                                      Ramada Boston       Poor
# 384         384                                      Ramada Boston   Terrible
# 385         385                                       Milner Hotel  Excellent
# 386         386                                       Milner Hotel  Very good
# 387         387                                       Milner Hotel    Average
# 388         388                                       Milner Hotel       Poor
# 389         389                                       Milner Hotel   Terrible
# 390         390      The Boston Common Hotel and Conference Center  Excellent
# 391         391      The Boston Common Hotel and Conference Center  Very good
# 392         392      The Boston Common Hotel and Conference Center    Average
# 393         393      The Boston Common Hotel and Conference Center       Poor
# 394         394      The Boston Common Hotel and Conference Center   Terrible
# 395         395                                   Constitution Inn  Excellent
# 396         396                                   Constitution Inn  Very good
# 397         397                                   Constitution Inn    Average
# 398         398                                   Constitution Inn       Poor
# 399         399                                   Constitution Inn   Terrible
# 400         400                            Americas Best Value Inn  Excellent
# 401         401                            Americas Best Value Inn  Very good
# 402         402                            Americas Best Value Inn    Average
# 403         403                            Americas Best Value Inn       Poor
# 404         404                            Americas Best Value Inn   Terrible
# 405         405                   Days Hotel Boston-Harvard Fenway  Excellent
# 406         406                   Days Hotel Boston-Harvard Fenway  Very good
# 407         407                   Days Hotel Boston-Harvard Fenway    Average
# 408         408                   Days Hotel Boston-Harvard Fenway       Poor
# 409         409                   Days Hotel Boston-Harvard Fenway   Terrible
#
#      count
# 0      509
# 1      175
# 2       13
# 3       13
# 4       12
# 5    1,281
# 6      230
# 7       55
# 8       20
# 9       16
# 10   3,084
# 11     733
# 12     132
# 13      50
# 14      37
# 15   1,136
# 16     197
# 17      53
# 18      27
# 19      17
# 20   2,188
# 21     551
# 22     120
# 23      45
# 24      20
# 25   1,058
# 26     376
# 27      62
# 28      16
# 29      15
# ..     ...
# 380     45
# 381     81
# 382     83
# 383     45
# 384     43
# 385     29
# 386    125
# 387    103
# 388     46
# 389     67
# 390     61
# 391    204
# 392    205
# 393     97
# 394     58
# 395     75
# 396    160
# 397    147
# 398     97
# 399     86
# 400      2
# 401      4
# 402      8
# 403      1
# 404      5
# 405     26
# 406     57
# 407    100
# 408     76
# 409     56
#
# [410 rows x 4 columns]

# %%
data['count'] = data['count'].apply(lambda x: x.replace(",", ""))

# %%
data = data[['hotel_name', 'rating', 'count']]
hotels = list(set(data['hotel_name'].values.tolist()))
avg_score = []
i = 0
while i < len(hotels):
    group = data.groupby('hotel_name').get_group(hotels[i])
    count = group['count'].values.tolist()
    count = list(map(int, count))
    score = (5*count[0] + 4*count[1] + 3*count[2] + 2*count[3] + 1*count[1])/sum(count)
    avg_score.append((hotels[i],score))
    i = i + 1

# %%
group = data.groupby('hotel_name').get_group(hotels[0])
group
# Out:
#                         hotel_name     rating count
# 230  Club Quarters Hotel in Boston  Excellent   687
# 231  Club Quarters Hotel in Boston  Very good   500
# 232  Club Quarters Hotel in Boston    Average   182
# 233  Club Quarters Hotel in Boston       Poor    66
# 234  Club Quarters Hotel in Boston   Terrible    50

# %%
feature = pd.read_csv('part2.csv')

# %%
groups = []
i = 0
while i < len(hotels):
    group = feature.groupby('hotel_name').get_group(hotels[i])
    groups.append((group['value_star'].mean(), group['location_star'].mean(), group['cleanliness_star'].mean()
                ,group['service_star'].mean(), group['rooms_star'].mean(), group['sleep_quality'].mean()))
    i = i + 1

# %%
feature.groupby('hotel_name').get_group(hotels[11])
# Out:
#                   hotel_name         review_id  value_star  location_star  \
# 41788   The Bostonian Boston  review_434155158         NaN            NaN
# 41789   The Bostonian Boston  review_434154028         NaN            5.0
# 41790   The Bostonian Boston  review_434027819         5.0            NaN
# 41791   The Bostonian Boston  review_433169881         3.0            5.0
# 41792   The Bostonian Boston  review_432950031         NaN            NaN
# 41793   The Bostonian Boston  review_432413090         NaN            NaN
# 41794   The Bostonian Boston  review_431371996         NaN            NaN
# 41795   The Bostonian Boston  review_431348069         NaN            NaN
# 41796   The Bostonian Boston  review_431027224         NaN            NaN
# 41797   The Bostonian Boston  review_430531691         5.0            5.0
# 41798   The Bostonian Boston  review_429758386         NaN            5.0
# 41799   The Bostonian Boston  review_429176946         NaN            5.0
# 41800   The Bostonian Boston  review_428867060         NaN            5.0
# 41801   The Bostonian Boston  review_427277153         5.0            NaN
# 41802   The Bostonian Boston  review_427070301         NaN            NaN
# 41803   The Bostonian Boston  review_425945501         NaN            5.0
# 41804   The Bostonian Boston  review_425655086         NaN            NaN
# 41805   The Bostonian Boston  review_425540397         NaN            NaN
# 41806   The Bostonian Boston  review_424650395         NaN            NaN
# 41807   The Bostonian Boston  review_424544245         NaN            NaN
# 41808   The Bostonian Boston  review_423872879         NaN            5.0
# 41809   The Bostonian Boston  review_423847646         NaN            NaN
# 41810   The Bostonian Boston  review_423411455         NaN            4.0
# 41811   The Bostonian Boston  review_422944753         NaN            4.0
# 41812   The Bostonian Boston  review_422420361         NaN            NaN
# 41813   The Bostonian Boston  review_420352170         4.0            5.0
# 41814   The Bostonian Boston  review_420319457         NaN            NaN
# 41815   The Bostonian Boston  review_419941687         3.0            5.0
# 41816   The Bostonian Boston  review_419242495         3.0            5.0
# 41817   The Bostonian Boston  review_418185523         4.0            NaN
# ...                      ...               ...         ...            ...
# 101737  The Bostonian Boston  review_116270760         5.0            NaN
# 101968  The Bostonian Boston   review_12172276         4.0            5.0
# 102008  The Bostonian Boston  review_349659609         NaN            NaN
# 102017  The Bostonian Boston  review_359503711         NaN            3.0
# 102100  The Bostonian Boston  review_172720641         3.0            5.0
# 102164  The Bostonian Boston   review_36276177         NaN            NaN
# 102191  The Bostonian Boston  review_140355495         4.0            5.0
# 102229  The Bostonian Boston  review_315070101         NaN            NaN
# 102294  The Bostonian Boston  review_283145778         NaN            NaN
# 102339  The Bostonian Boston   review_85619966         3.0            5.0
# 102405  The Bostonian Boston    review_5438574         NaN            NaN
# 102557  The Bostonian Boston  review_300205458         NaN            5.0
# 102564  The Bostonian Boston  review_287032934         NaN            NaN
# 102582  The Bostonian Boston  review_174520023         3.0            5.0
# 102608  The Bostonian Boston  review_217299228         3.0            5.0
# 102747  The Bostonian Boston   review_13543646         5.0            5.0
# 102753  The Bostonian Boston  review_322631602         NaN            NaN
# 102825  The Bostonian Boston  review_208321362         4.0            4.0
# 102835  The Bostonian Boston    review_6472369         2.0            5.0
# 102911  The Bostonian Boston    review_3344943         3.0            NaN
# 103038  The Bostonian Boston   review_97035265         4.0            5.0
# 103064  The Bostonian Boston  review_122677757         5.0            5.0
# 103139  The Bostonian Boston  review_226785011         NaN            NaN
# 103200  The Bostonian Boston   review_35747928         4.0            5.0
# 103209  The Bostonian Boston  review_264848385         NaN            4.0
# 103357  The Bostonian Boston  review_275029904         5.0            NaN
# 103362  The Bostonian Boston  review_349061882         NaN            NaN
# 103500  The Bostonian Boston  review_413351741         NaN            NaN
# 103512  The Bostonian Boston  review_155445815         3.0            5.0
# 103623  The Bostonian Boston  review_132917859         2.0            5.0
#
#         cleanliness_star  service_star  rooms_star  sleep_quality
# 41788                NaN           3.0         4.0            4.0
# 41789                5.0           5.0         NaN            NaN
# 41790                NaN           5.0         NaN            5.0
# 41791                NaN           4.0         NaN            NaN
# 41792                NaN           NaN         NaN            NaN
# 41793                3.0           3.0         3.0            NaN
# 41794                NaN           NaN         NaN            NaN
# 41795                NaN           5.0         5.0            5.0
# 41796                NaN           NaN         NaN            NaN
# 41797                NaN           4.0         NaN            NaN
# 41798                NaN           5.0         4.0            NaN
# 41799                5.0           5.0         NaN            NaN
# 41800                5.0           5.0         NaN            NaN
# 41801                5.0           5.0         NaN            NaN
# 41802                NaN           NaN         NaN            NaN
# 41803                5.0           4.0         NaN            NaN
# 41804                NaN           NaN         NaN            NaN
# 41805                NaN           NaN         NaN            NaN
# 41806                NaN           NaN         NaN            NaN
# 41807                NaN           NaN         NaN            NaN
# 41808                NaN           3.0         NaN            1.0
# 41809                5.0           3.0         NaN            4.0
# 41810                5.0           5.0         NaN            NaN
# 41811                NaN           4.0         4.0            NaN
# 41812                NaN           NaN         NaN            NaN
# 41813                NaN           5.0         NaN            NaN
# 41814                NaN           NaN         NaN            NaN
# 41815                NaN           5.0         NaN            NaN
# 41816                NaN           5.0         NaN            NaN
# 41817                5.0           5.0         NaN            NaN
# ...                  ...           ...         ...            ...
# 101737               5.0           5.0         NaN            4.0
# 101968               4.0           5.0         5.0            NaN
# 102008               NaN           5.0         4.0            4.0
# 102017               NaN           2.0         3.0            NaN
# 102100               5.0           3.0         5.0            5.0
# 102164               NaN           NaN         NaN            NaN
# 102191               5.0           5.0         4.0            5.0
# 102229               NaN           NaN         NaN            NaN
# 102294               NaN           NaN         NaN            NaN
# 102339               4.0           2.0         4.0            4.0
# 102405               NaN           NaN         NaN            NaN
# 102557               NaN           5.0         5.0            NaN
# 102564               NaN           NaN         NaN            NaN
# 102582               5.0           3.0         5.0            4.0
# 102608               NaN           5.0         NaN            NaN
# 102747               5.0           5.0         5.0            NaN
# 102753               NaN           NaN         NaN            NaN
# 102825               4.0           4.0         4.0            4.0
# 102835               3.0           NaN         3.0            NaN
# 102911               2.0           3.0         3.0            NaN
# 103038               5.0           4.0         5.0            2.0
# 103064               5.0           5.0         5.0            5.0
# 103139               NaN           NaN         NaN            NaN
# 103200               5.0           4.0         5.0            NaN
# 103209               NaN           1.0         NaN            2.0
# 103357               NaN           5.0         5.0            NaN
# 103362               NaN           NaN         NaN            NaN
# 103500               NaN           NaN         NaN            NaN
# 103512               5.0           3.0         4.0            5.0
# 103623               5.0           4.0         4.0            5.0
#
# [1946 rows x 8 columns]

# %%
for i in range(len(groups)):
    groups[i] = avg_score[i] + groups[i]

# %%
df_feature = pd.DataFrame(groups, columns = ['hotel_name', 'avg_score','value_star','location_star','cleanliness_star','service_star','rooms_star','sleep_quality'])

# %%
df_feature = df_feature.dropna(how = 'any')

# %%
from sklearn import linear_model
attributes = ['value_star','location_star','cleanliness_star','service_star','rooms_star','sleep_quality']
X = df_feature[['value_star','location_star','cleanliness_star','service_star','rooms_star','sleep_quality']]
Y = df_feature['avg_score']

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
y_train_pred = regr.predict(X_train)
y_test_pred = regr.predict(X_test)
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print('MSE train: %.3f, test: %.3f' %(mean_squared_error(Y_train, y_train_pred),
                                      mean_squared_error(Y_test, y_test_pred)))
 
print('R^2 train: %.3f, test: %.3f' %(r2_score(Y_train, y_train_pred),
                                      r2_score(Y_test, y_test_pred)))
# Out:
# MSE train: 0.007, test: 0.016
# R^2 train: 0.951, test: 0.932

# %%
import statsmodels.formula.api as sm
model = sm.OLS(Y_train, X_train)
results = model.fit()
print(results.summary())
#notice that there are significant evidence that location_star, rooms_star and cleaniness have an effect on avg_score
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avg_score   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.345e+04
# Date:                Tue, 15 Nov 2016   Prob (F-statistic):           2.03e-84
# Time:                        20:38:51   Log-Likelihood:                 59.103
# No. Observations:                  56   AIC:                            -106.2
# Df Residuals:                      50   BIC:                            -94.05
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# value_star           0.1004      0.070      1.438      0.157        -0.040     0.241
# location_star        0.1067      0.041      2.610      0.012         0.025     0.189
# cleanliness_star     0.4243      0.089      4.764      0.000         0.245     0.603
# service_star         0.0765      0.105      0.731      0.468        -0.134     0.287
# rooms_star           0.0600      0.088      0.679      0.500        -0.117     0.237
# sleep_quality        0.2607      0.104      2.519      0.015         0.053     0.469
# ==============================================================================
# Omnibus:                       21.065   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.317
# Skew:                          -1.087   Prob(JB):                     2.38e-10
# Kurtosis:                       6.777   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model1 = sm.OLS(Y_train, X_train[['value_star', 'service_star', 'sleep_quality']])
results = model1.fit()
print(results.summary())
#regress avg_score on insignificant features above, and find service_star and sleep_quality
#are significant now
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avg_score   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.775e+04
# Date:                Tue, 15 Nov 2016   Prob (F-statistic):           1.16e-84
# Time:                        20:37:50   Log-Likelihood:                 42.786
# No. Observations:                  56   AIC:                            -79.57
# Df Residuals:                      53   BIC:                            -73.50
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# value_star        0.1713      0.088      1.947      0.057        -0.005     0.348
# service_star      0.3844      0.119      3.235      0.002         0.146     0.623
# sleep_quality     0.4965      0.092      5.401      0.000         0.312     0.681
# ==============================================================================
# Omnibus:                       23.712   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.602
# Skew:                          -1.354   Prob(JB):                     5.61e-10
# Kurtosis:                       6.306   Cond. No.                         69.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model2 = sm.OLS(Y_train, X_train['value_star'])
results = model2.fit()
print(results.summary())
#if we only regress on value_star, then it is also significant, and itself explains 99.5% variation
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avg_score   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 2.340e+04
# Date:                Tue, 15 Nov 2016   Prob (F-statistic):           5.13e-74
# Time:                        20:37:50   Log-Likelihood:                 6.2567
# No. Observations:                  56   AIC:                            -10.51
# Df Residuals:                      55   BIC:                            -8.488
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# value_star     1.1227      0.007    152.961      0.000         1.108     1.137
# ==============================================================================
# Omnibus:                       23.606   Durbin-Watson:                   2.445
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.434
# Skew:                          -1.346   Prob(JB):                     6.10e-10
# Kurtosis:                       6.307   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# In conclusion, all six features have an effect on the average score, but the features themselves are highly correlated, so if we regress avg_score on all of them, only some of them are significant, because the rest features have nothing to explain. However, if we regress avg_score on any feature individually, every feature will have a significantly contribution to avg_score.

# %% [markdown]
# -------

# %% [markdown]
# ** Task 3 (30 pts) **
#
# Finally, we will use logistic regression to decide if a hotel is _excellent_ or not. We classify a hotel as _excellent_ if more than **60%** of its ratings are 5 stars. This is a binary attribute on which we can fit a logistic regression model. As before, use the model to analyze the data.

# %%
label = []
i = 0
while i < len(hotels):
    group = data.groupby('hotel_name').get_group(hotels[i])
    count = group['count'].values.tolist()
    count = list(map(int, count))
    pct_excellent = count[0]/sum(count)
    if pct_excellent > 0.6:
        label.append((hotels[i],'Excellent'))
    else:
        label.append((hotels[i],'Not_excellent'))
    i = i + 1

# %%
for i in range(len(groups)):
    groups[i] = label[i] + groups[i][2:]

# %%
df_part2 = pd.DataFrame(groups, columns = ['hotel_name', 'label','value_star','location_star','cleanliness_star','service_star','rooms_star','sleep_quality'])

# %%
df_part2 = df_part2.dropna(how = 'any')

# %%
X2 = df_part2[['value_star','location_star','cleanliness_star','service_star','rooms_star','sleep_quality']]
Y2 = df_part2['label']

# %%
from sklearn.linear_model import LogisticRegression
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=0.3, random_state=1)

# %%
lr = LogisticRegression(C=1000, random_state=0)
lr.fit(X_train2, y_train2)
# Out:
# LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lr.predict(X_test2)
print('Number of misclassified samples: %d' % (y_test2 != y_pred).sum())
from sklearn.metrics import accuracy_score

print('Accuracy: %.2f' % accuracy_score(y_test2, y_pred))    

print('Coefficients: \n', lr.coef_)
#Works very well!
# Out:
# Number of misclassified samples: 0
# Accuracy: 1.00
# Coefficients:
#  [[-1.97668908 -1.24161023  4.70915864 -6.65381942 -2.61542549 -7.71429434]]

# %%
for i in range(len(Y2.values)):
    if Y2.values[i] == 'Not_excellent':
        Y2.values[i] = 0
    else:
        Y2.values[i] = 1
Y2 = Y2.astype('int64')

# %%
import statsmodels.api as sm
#Look at the detailed summary of the model
logit = sm.OLS(Y2,X2)

# %%
result1 = logit.fit() 
print (result1.summary())
# only room_star and cleanliness star are significant!
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  label   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     13.43
# Date:                Tue, 15 Nov 2016   Prob (F-statistic):           2.79e-10
# Time:                        20:46:54   Log-Likelihood:                -39.355
# No. Observations:                  81   AIC:                             90.71
# Df Residuals:                      75   BIC:                             105.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# value_star          -0.0422      0.263     -0.161      0.873        -0.566     0.482
# location_star        0.0041      0.139      0.030      0.976        -0.273     0.281
# cleanliness_star    -1.0354      0.332     -3.120      0.003        -1.697    -0.374
# service_star         0.3329      0.415      0.802      0.425        -0.494     1.160
# rooms_star           1.2050      0.290      4.154      0.000         0.627     1.783
# sleep_quality       -0.3175      0.356     -0.891      0.376        -1.028     0.393
# ==============================================================================
# Omnibus:                       28.323   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.189
# Skew:                           0.291   Prob(JB):                       0.0453
# Kurtosis:                       1.778   Cond. No.                         108.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
logit2 = sm.OLS(Y2,X2[['value_star', 'location_star', 'service_star', 'sleep_quality']])
result2 = logit2.fit() 
print (result2.summary())
#None of them are significant!
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  label   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     12.23
# Date:                Tue, 15 Nov 2016   Prob (F-statistic):           9.58e-08
# Time:                        20:53:47   Log-Likelihood:                -48.997
# No. Observations:                  81   AIC:                             106.0
# Df Residuals:                      77   BIC:                             115.6
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# value_star       -0.2204      0.288     -0.765      0.447        -0.794     0.353
# location_star    -0.1869      0.140     -1.337      0.185        -0.465     0.091
# service_star      0.2985      0.411      0.726      0.470        -0.520     1.118
# sleep_quality     0.1785      0.311      0.573      0.568        -0.441     0.798
# ==============================================================================
# Omnibus:                       67.354   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.638
# Skew:                           0.673   Prob(JB):                      0.00180
# Kurtosis:                       1.610   Cond. No.                         84.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Therefore, we can conclude that only room_star and cleanliness_star have a significant influence on whether a hotel is excellent or not!

# %% [markdown]
# -------
